# %%
# NOTE: PLEASE MAKE SURE YOU ARE RUNNING THIS IN A PYTHON3 ENVIRONMENT
# %tensorflow_version 2.x
import tensorflow as tf
print(tf.__version__)

# This is needed for the iterator over the data
# But not necessary if you have TF 2.0 installed
#!pip install tensorflow==2.0.0-beta0


# tf.enable_eager_execution()

# !pip install -q tensorflow-datasets
# Out:
# TensorFlow 2.x selected.
# 2.1.0

# %%
import tensorflow_datasets as tfds
imdb, info = tfds.load("imdb_reviews", with_info=True, as_supervised=True)
# Out:
# Downloading and preparing dataset imdb_reviews (80.23 MiB) to /root/tensorflow_datasets/imdb_reviews/plain_text/1.0.0...
# HBox(children=(IntProgress(value=1, bar_style='info', description='Dl Completed...', max=1, style=ProgressStyl…
# HBox(children=(IntProgress(value=1, bar_style='info', description='Dl Size...', max=1, style=ProgressStyle(des…
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# Shuffling and writing examples to /root/tensorflow_datasets/imdb_reviews/plain_text/1.0.0.incompleteUA9IFU/imdb_reviews-train.tfrecord
# HBox(children=(IntProgress(value=0, max=25000), HTML(value='')))
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# Shuffling and writing examples to /root/tensorflow_datasets/imdb_reviews/plain_text/1.0.0.incompleteUA9IFU/imdb_reviews-test.tfrecord
# HBox(children=(IntProgress(value=0, max=25000), HTML(value='')))
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# Shuffling and writing examples to /root/tensorflow_datasets/imdb_reviews/plain_text/1.0.0.incompleteUA9IFU/imdb_reviews-unsupervised.tfrecord
# HBox(children=(IntProgress(value=0, max=50000), HTML(value='')))
# Dataset imdb_reviews downloaded and prepared to /root/tensorflow_datasets/imdb_reviews/plain_text/1.0.0. Subsequent calls will reuse this data.

# %%
import numpy as np

train_data, test_data = imdb['train'], imdb['test']

training_sentences = []
training_labels = []

testing_sentences = []
testing_labels = []

# str(s.tonumpy()) is needed in Python3 instead of just s.numpy()
for s,l in train_data:
  training_sentences.append(str(s.numpy()))
  training_labels.append(l.numpy())
  
for s,l in test_data:
  testing_sentences.append(str(s.numpy()))
  testing_labels.append(l.numpy())
  
training_labels_final = np.array(training_labels)
testing_labels_final = np.array(testing_labels)

# %%
vocab_size = 10000
embedding_dim = 16
max_length = 120
trunc_type='post'
oov_tok = "<OOV>"


from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

tokenizer = Tokenizer(num_words = vocab_size, oov_token=oov_tok)
tokenizer.fit_on_texts(training_sentences)
word_index = tokenizer.word_index
sequences = tokenizer.texts_to_sequences(training_sentences)
padded = pad_sequences(sequences,maxlen=max_length, truncating=trunc_type)

testing_sequences = tokenizer.texts_to_sequences(testing_sentences)
testing_padded = pad_sequences(testing_sequences,maxlen=max_length)

# %%
reverse_word_index = dict([(value, key) for (key, value) in word_index.items()])

def decode_review(text):
    return ' '.join([reverse_word_index.get(i, '?') for i in text])

print(decode_review(padded[1]))
print(training_sentences[1])
# Out:
# ? ? ? ? ? ? ? b'i have been known to fall asleep during films but this is usually due to a combination of things including really tired being warm and comfortable on the <OOV> and having just eaten a lot however on this occasion i fell asleep because the film was rubbish the plot development was constant constantly slow and boring things seemed to happen but with no explanation of what was causing them or why i admit i may have missed part of the film but i watched the majority of it and everything just seemed to happen of its own <OOV> without any real concern for anything else i cant recommend this film at all '
# b'I have been known to fall asleep during films, but this is usually due to a combination of things including, really tired, being warm and comfortable on the sette and having just eaten a lot. However on this occasion I fell asleep because the film was rubbish. The plot development was constant. Constantly slow and boring. Things seemed to happen, but with no explanation of what was causing them or why. I admit, I may have missed part of the film, but i watched the majority of it and everything just seemed to happen of its own accord without any real concern for anything else. I cant recommend this film at all.'

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_length),
    tf.keras.layers.Bidirectional(tf.keras.layers.GRU(32)),
    tf.keras.layers.Dense(6, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 120, 16)           160000
# _________________________________________________________________
# bidirectional (Bidirectional (None, 64)                9600
# _________________________________________________________________
# dense (Dense)                (None, 6)                 390
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 7
# =================================================================
# Total params: 169,997
# Trainable params: 169,997
# Non-trainable params: 0
# _________________________________________________________________

# %%
num_epochs = 50
history = model.fit(padded, training_labels_final, epochs=num_epochs, validation_data=(testing_padded, testing_labels_final))
# Out:
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/50
# 25000/25000 [==============================] - 26s 1ms/sample - loss: 0.5595 - accuracy: 0.6732 - val_loss: 0.3873 - val_accuracy: 0.8211
# Epoch 2/50
# 25000/25000 [==============================] - 17s 687us/sample - loss: 0.3213 - accuracy: 0.8648 - val_loss: 0.3507 - val_accuracy: 0.8449
# Epoch 3/50
# 25000/25000 [==============================] - 17s 678us/sample - loss: 0.2463 - accuracy: 0.9043 - val_loss: 0.3733 - val_accuracy: 0.8423
# Epoch 4/50
# 25000/25000 [==============================] - 17s 671us/sample - loss: 0.1934 - accuracy: 0.9308 - val_loss: 0.4345 - val_accuracy: 0.8240
# Epoch 5/50
# 25000/25000 [==============================] - 17s 665us/sample - loss: 0.1480 - accuracy: 0.9485 - val_loss: 0.4662 - val_accuracy: 0.8171
# Epoch 6/50
# 25000/25000 [==============================] - 17s 683us/sample - loss: 0.1069 - accuracy: 0.9652 - val_loss: 0.5532 - val_accuracy: 0.8247
# Epoch 7/50
# 25000/25000 [==============================] - 17s 666us/sample - loss: 0.0752 - accuracy: 0.9760 - val_loss: 0.6212 - val_accuracy: 0.8182
# Epoch 8/50
# 25000/25000 [==============================] - 17s 675us/sample - loss: 0.0544 - accuracy: 0.9828 - val_loss: 0.7254 - val_accuracy: 0.8126
# Epoch 9/50
# 25000/25000 [==============================] - 17s 673us/sample - loss: 0.0428 - accuracy: 0.9865 - val_loss: 0.7338 - val_accuracy: 0.8136
# Epoch 10/50
# 25000/25000 [==============================] - 17s 663us/sample - loss: 0.0308 - accuracy: 0.9900 - val_loss: 0.8220 - val_accuracy: 0.8048
# Epoch 11/50
# 25000/25000 [==============================] - 17s 668us/sample - loss: 0.0254 - accuracy: 0.9919 - val_loss: 0.8798 - val_accuracy: 0.8092
# Epoch 12/50
# 25000/25000 [==============================] - 17s 662us/sample - loss: 0.0172 - accuracy: 0.9948 - val_loss: 0.9334 - val_accuracy: 0.8040
# Epoch 13/50
# 25000/25000 [==============================] - 17s 678us/sample - loss: 0.0125 - accuracy: 0.9962 - val_loss: 1.0582 - val_accuracy: 0.8105
# Epoch 14/50
# 25000/25000 [==============================] - 16s 655us/sample - loss: 0.0119 - accuracy: 0.9959 - val_loss: 1.1563 - val_accuracy: 0.8106
# Epoch 15/50
# 25000/25000 [==============================] - 17s 687us/sample - loss: 0.0136 - accuracy: 0.9956 - val_loss: 1.1710 - val_accuracy: 0.8064
# Epoch 16/50
# 25000/25000 [==============================] - 17s 679us/sample - loss: 0.0113 - accuracy: 0.9966 - val_loss: 1.2534 - val_accuracy: 0.8083
# Epoch 17/50
# 25000/25000 [==============================] - 17s 670us/sample - loss: 0.0096 - accuracy: 0.9969 - val_loss: 1.1467 - val_accuracy: 0.8124
# Epoch 18/50
# 25000/25000 [==============================] - 17s 696us/sample - loss: 0.0075 - accuracy: 0.9973 - val_loss: 1.2407 - val_accuracy: 0.8044
# Epoch 19/50
# 25000/25000 [==============================] - 17s 672us/sample - loss: 0.0066 - accuracy: 0.9979 - val_loss: 1.2790 - val_accuracy: 0.8064
# Epoch 20/50
# 25000/25000 [==============================] - 17s 678us/sample - loss: 0.0088 - accuracy: 0.9971 - val_loss: 1.4191 - val_accuracy: 0.7908
# Epoch 21/50
# 25000/25000 [==============================] - 17s 662us/sample - loss: 0.0104 - accuracy: 0.9966 - val_loss: 1.2304 - val_accuracy: 0.8054
# Epoch 22/50
# 25000/25000 [==============================] - 17s 696us/sample - loss: 0.0041 - accuracy: 0.9987 - val_loss: 1.2886 - val_accuracy: 0.8056
# Epoch 23/50
# 25000/25000 [==============================] - 17s 683us/sample - loss: 0.0016 - accuracy: 0.9996 - val_loss: 1.4180 - val_accuracy: 0.8089
# Epoch 24/50
# 25000/25000 [==============================] - 17s 687us/sample - loss: 5.4755e-04 - accuracy: 0.9999 - val_loss: 1.6044 - val_accuracy: 0.8108
# Epoch 25/50
# 25000/25000 [==============================] - 17s 682us/sample - loss: 0.0120 - accuracy: 0.9958 - val_loss: 1.3396 - val_accuracy: 0.8097
# Epoch 26/50
# 25000/25000 [==============================] - 17s 675us/sample - loss: 0.0076 - accuracy: 0.9976 - val_loss: 1.4029 - val_accuracy: 0.8047
# Epoch 27/50
# 25000/25000 [==============================] - 17s 695us/sample - loss: 0.0064 - accuracy: 0.9980 - val_loss: 1.4644 - val_accuracy: 0.7936
# Epoch 28/50
# 25000/25000 [==============================] - 17s 688us/sample - loss: 0.0016 - accuracy: 0.9995 - val_loss: 1.4506 - val_accuracy: 0.8099
# Epoch 29/50
# 25000/25000 [==============================] - 17s 677us/sample - loss: 3.1697e-04 - accuracy: 1.0000 - val_loss: 1.5284 - val_accuracy: 0.8069
# Epoch 30/50
# 25000/25000 [==============================] - 17s 688us/sample - loss: 8.4069e-05 - accuracy: 1.0000 - val_loss: 1.5720 - val_accuracy: 0.8084
# Epoch 31/50
# 25000/25000 [==============================] - 17s 688us/sample - loss: 3.2331e-05 - accuracy: 1.0000 - val_loss: 1.6333 - val_accuracy: 0.8091
# Epoch 32/50
# 25000/25000 [==============================] - 17s 685us/sample - loss: 2.0428e-05 - accuracy: 1.0000 - val_loss: 1.6863 - val_accuracy: 0.8095
# Epoch 33/50
# 25000/25000 [==============================] - 17s 679us/sample - loss: 1.4068e-05 - accuracy: 1.0000 - val_loss: 1.7398 - val_accuracy: 0.8093
# Epoch 34/50
# 25000/25000 [==============================] - 17s 698us/sample - loss: 9.6220e-06 - accuracy: 1.0000 - val_loss: 1.7982 - val_accuracy: 0.8098
# Epoch 35/50
# 25000/25000 [==============================] - 17s 673us/sample - loss: 6.6195e-06 - accuracy: 1.0000 - val_loss: 1.8592 - val_accuracy: 0.8099
# Epoch 36/50
# 25000/25000 [==============================] - 17s 696us/sample - loss: 4.5120e-06 - accuracy: 1.0000 - val_loss: 1.9123 - val_accuracy: 0.8094
# Epoch 37/50
# 25000/25000 [==============================] - 17s 686us/sample - loss: 3.0409e-06 - accuracy: 1.0000 - val_loss: 1.9783 - val_accuracy: 0.8094
# Epoch 38/50
# 25000/25000 [==============================] - 17s 678us/sample - loss: 2.0228e-06 - accuracy: 1.0000 - val_loss: 2.0406 - val_accuracy: 0.8092
# Epoch 39/50
# 25000/25000 [==============================] - 17s 671us/sample - loss: 1.3425e-06 - accuracy: 1.0000 - val_loss: 2.1045 - val_accuracy: 0.8093
# Epoch 40/50
# 25000/25000 [==============================] - 17s 666us/sample - loss: 8.8548e-07 - accuracy: 1.0000 - val_loss: 2.1688 - val_accuracy: 0.8091
# Epoch 41/50
# 25000/25000 [==============================] - 17s 683us/sample - loss: 5.8093e-07 - accuracy: 1.0000 - val_loss: 2.2320 - val_accuracy: 0.8087
# Epoch 42/50
# 25000/25000 [==============================] - 17s 668us/sample - loss: 3.8176e-07 - accuracy: 1.0000 - val_loss: 2.2924 - val_accuracy: 0.8087
# Epoch 43/50
# 25000/25000 [==============================] - 17s 671us/sample - loss: 2.5099e-07 - accuracy: 1.0000 - val_loss: 2.3624 - val_accuracy: 0.8087
# Epoch 44/50
# 25000/25000 [==============================] - 17s 662us/sample - loss: 1.6516e-07 - accuracy: 1.0000 - val_loss: 2.4262 - val_accuracy: 0.8088
# Epoch 45/50
# 25000/25000 [==============================] - 17s 671us/sample - loss: 1.0864e-07 - accuracy: 1.0000 - val_loss: 2.4853 - val_accuracy: 0.8089
# Epoch 46/50
# 25000/25000 [==============================] - 17s 669us/sample - loss: 7.2416e-08 - accuracy: 1.0000 - val_loss: 2.5501 - val_accuracy: 0.8090
# Epoch 47/50
# 25000/25000 [==============================] - 17s 670us/sample - loss: 4.8325e-08 - accuracy: 1.0000 - val_loss: 2.6098 - val_accuracy: 0.8088
# Epoch 48/50
# 25000/25000 [==============================] - 17s 674us/sample - loss: 3.2806e-08 - accuracy: 1.0000 - val_loss: 2.6756 - val_accuracy: 0.8087
# Epoch 49/50
# 25000/25000 [==============================] - 17s 668us/sample - loss: 2.2389e-08 - accuracy: 1.0000 - val_loss: 2.7327 - val_accuracy: 0.8090
# Epoch 50/50
# 25000/25000 [==============================] - 17s 664us/sample - loss: 1.5481e-08 - accuracy: 1.0000 - val_loss: 2.7810 - val_accuracy: 0.8088

# %%
import matplotlib.pyplot as plt


def plot_graphs(history, string):
  plt.plot(history.history[string])
  plt.plot(history.history['val_'+string])
  plt.xlabel("Epochs")
  plt.ylabel(string)
  plt.legend([string, 'val_'+string])
  plt.show()

plot_graphs(history, 'accuracy')
plot_graphs(history, 'loss')

# %%
# Model Definition with LSTM
model = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_length),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32)),
    tf.keras.layers.Dense(6, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 120, 16)           160000
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, 64)                12544
# _________________________________________________________________
# dense_2 (Dense)              (None, 6)                 390
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 7
# =================================================================
# Total params: 172,941
# Trainable params: 172,941
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Model Definition with Conv1D
model = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_length),
    tf.keras.layers.Conv1D(128, 5, activation='relu'),
    tf.keras.layers.GlobalAveragePooling1D(),
    tf.keras.layers.Dense(6, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_2 (Embedding)      (None, 120, 16)           160000
# _________________________________________________________________
# conv1d (Conv1D)              (None, 116, 128)          10368
# _________________________________________________________________
# global_average_pooling1d (Gl (None, 128)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 6)                 774
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 7
# =================================================================
# Total params: 171,149
# Trainable params: 171,149
# Non-trainable params: 0
# _________________________________________________________________
